# %%
import var_code as VC
import numpy as np
import numba as nb
import os

# %%
# %%time
ms = [300.]
mixangle = [5.e-5]

print("Mass = {} MeV; Lifetime = {:.3} s".format(ms[0],VC.ts(ms[0],mixangle[0])*6.58e-22))
    
fn = "../{}-{:.4}-FullTestNew/{}-{:.4}-FullTestNew/".format(ms[0],mixangle[0],ms[0],mixangle[0])

if not os.path.exists(fn):
    os.makedirs(fn)
else:
    print("Folder {} already exists.  Overwriting any data".format(fn))
VC.babysteps(ms[0],mixangle[0],200,100,100,fn+"full")
# Out:
# Mass = 300.0 MeV; Lifetime = 0.0598 s
# Folder ../300.0-5e-05-FullTestNew/300.0-5e-05-FullTestNew/ already exists.  Overwriting any data
# Initial Run. Tcm = 15.000 MeV, eps_s = 138, eps_b = 184
# f_FULL =  0.019772287636017672 a0 =  0.06666666666666667 a_max =  0.13333333333333333
# 0.0 0.0 0.0 0.5
# 1 0.06724394049343899 6.0382008831788374e-06
# Run time: 0.114 hrs
# Run 1 of 200. Tcm = 14.871 MeV, T= 14.872 MeV, t/tau = 0.001, eps_s = 138, eps_b = 184
# f_FULL =  0.019414884828463954 a0 =  0.06724394049343899 a_max =  0.13448788098687797
# [93, 116, 139]
# 46.5 58.0 69.5 0.5
# a_array =  [0.06724394 0.06783238 0.06845386 0.06909384 0.06975316 0.07043276
#  0.07113364 0.07185687 0.07260359 0.07337507 0.07417262 0.07499767
#  0.07585178 0.07673663 0.07765408 0.07860609 0.07959481 0.0806226
#  0.08169209 0.08280609 0.08396768 0.08518029 0.0864479  0.08777453
#  0.08916485 0.09062447 0.09215889 0.0937748  0.09548043 0.0972833
# ...
